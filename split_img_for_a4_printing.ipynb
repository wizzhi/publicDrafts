# %% [markdown]
# # Splitting big images into smaller pieces that are suitable to be printed out on A4 paper.

# %%
from PIL import Image
import os

Image.MAX_IMAGE_PIXELS = None

# %%
def split_img_A4(input_file_path, output_file_prefix):
    # A4 size = 210mm x 297mm
    a4_width_in = 8.27
    a4_height_in = 11.69

    # Open the image
    img = Image.open(input_file_path)
    img_width, img_height = img.size
    print(f"原始像素：{img_width} x {img_height}")
    origin_dpi = img.info.get('dpi')
    print(f"原始 dpi：{origin_dpi}")

    dpi = 300
    print(f"假设打印 dpi：{dpi}")
    # Calculate dimensions based on DPI
    a4_width_px = int(a4_width_in * dpi )
    a4_height_px = int(a4_height_in * dpi )

    pages1,w1,h1 = estimate_splits(img_width, img_height, a4_width_px, a4_height_px)
    pages2,w2,h2 = estimate_splits(img_width, img_height, a4_height_px, a4_width_px)

    print()
    print("由于", end='')
    if pages1 < pages2:
        print("方案 1 比较节约纸张", end='')
        a4_width_px = w1
        a4_height_px = h1
    elif pages1 == pages2:
        if max(w1,h1) < max(w2,h2):
            print("方案 1 在使用相同纸张情况下压缩较小", end='')
            a4_width_px = w1
            a4_height_px = h1
        else:
            print("方案 2 在使用相同纸张情况下压缩较小", end='')
            a4_width_px = w2
            a4_height_px = h2
    else:
        print("方案 2 比较节约纸张", end='')
        a4_width_px = w2
        a4_height_px = h2
    
    # Calculate number of tiles needed
    num_tiles_w = (img_width + a4_width_px - 1) // a4_width_px
    num_tiles_h = (img_height + a4_height_px - 1) // a4_height_px
    print(f"，总共切割成：{num_tiles_w} x {num_tiles_h} = {num_tiles_w*num_tiles_h} 张图片。每张大约：{w2} x {h2} 像素")
    
    
    # Split and save tiles
    for w in range(num_tiles_w):
        for h in range(num_tiles_h):
            # Calculate the coordinates for each tile
            left = w * a4_width_px
            top = h * a4_height_px
            right = left + a4_width_px
            bottom = top + a4_height_px
            
            # Crop the image to the current tile
            tile = img.crop((left, top, right, bottom))
            
            # Save the tile
            output_path = f"{output_file_prefix}_{h+1}-{w+1}.png"
            tile.save(output_path)
            print( '=' if a4_width_px>a4_height_px else '║', end='', flush=True)
        print()
    print("完成\n")

def estimate_splits(img_w,img_h,paper_w,paper_h):
    print()
    print(f"假如切割成：{paper_w} x {paper_h} ({'=' if paper_w>paper_h else '║'})")
    pages_w = (img_w + paper_w - 1) // paper_w
    width_res = (img_w % paper_w)/img_w
    print(f"水平页数：{pages_w} 最右一帧占总宽：{width_res:%}")
    pages_h = (img_h + paper_h - 1) // paper_h
    height_res = (img_h % paper_h)/img_h
    print(f"垂直页数：{pages_h} 最下一帧占总高：{height_res:%}")

    # 如果最后一帧内容小于tolerance，那就压缩画面节约纸张
    tolerance = 0.25
    if pages_h <=1 or pages_h <=1:
        return pages_w*pages_h, paper_w, paper_h
    if width_res <= tolerance and height_res <= tolerance:
        # 选取节约纸多的方式
        if pages_h > pages_w:
            #上下分页多就压宽度
            pages_h -= 1
            comparess_rate = width_res
        else:
            #左右分页多就压高度
            pages_w -= 1
            comparess_rate = height_res
    elif width_res <= tolerance:
        pages_h -= 1
        comparess_rate = width_res
    elif height_res <= tolerance:
        pages_w -= 1
        comparess_rate = height_res
    else:
        comparess_rate = 0
    
    if comparess_rate > 0:
        print(f"可以考虑压缩 {comparess_rate:.1%} 以提高纸张利用率")
        comparess_rate += 0.01
        paper_w *= (comparess_rate+1)
        paper_h *= (comparess_rate+1)

    return pages_w*pages_h, int(paper_w), int(paper_h)


split_img_A4("3.jpg", './tst')
# Out:
# 原始像素：19821 x 31417
# 原始 dpi：(300, 300)
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：8 最右一帧占总宽：12.380808%
# 垂直页数：9 最下一帧占总高：10.698030%
# 可以考虑压缩 12.4% 以提高纸张利用率
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：6 最右一帧占总宽：11.533222%
# 垂直页数：13 最下一帧占总高：5.236019%
# 可以考虑压缩 11.5% 以提高纸张利用率
#
# 由于方案 1 比较节约纸张，总共切割成：8 x 8 = 64 张图片。每张大约：3946 x 2791 像素
# ║║║║║║║║
# ║║║║║║║║
# ║║║║║║║║
# ║║║║║║║║
# ║║║║║║║║
# ║║║║║║║║
# ║║║║║║║║
# ║║║║║║║║
# 完成

# %%
img_folder =    "/Users/I070019/Downloads/temp/道法思维导图（全）"
output_folder = "/Users/I070019/Downloads/temp/toBePrinted"

image_extensions = ['.jpg', '.jpeg', '.png', '.gif', '.bmp']

os.makedirs(output_folder, exist_ok=True)

def find_image_files(directory):
    # 遍历当前目录中的所有项目
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        
        # 检查是否是文件
        if os.path.isfile(file_path):
            # 获取扩展名并转换为小写
            ext = os.path.splitext(filename)[1].lower()
            
            # 如果是图像文件
            if ext in image_extensions:
                print(f"处理图像文件: {file_path}")
                name_from_path  = file_path[ len(img_folder)+1: -len(ext)].replace(os.path.sep, '_')
                split_img_A4(file_path, f"{output_folder}/{name_from_path}")
        
        # 检查是否是目录，如果是，则递归处理子目录
        elif os.path.isdir(file_path):
            find_image_files(file_path)

# 调用函数开始查找
find_image_files(img_folder)
# Out:
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/七年级道法思维导图/七下道法思维导图/第四单元 走进法治天地 .png
# 原始像素：3932 x 6080
# 原始 dpi：None
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：2 最右一帧占总宽：36.902340%
# 垂直页数：2 最下一帧占总高：42.319079%
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：2 最右一帧占总宽：10.808749%
# 垂直页数：3 最下一帧占总高：18.388158%
# 可以考虑压缩 10.8% 以提高纸张利用率
#
# 由于方案 1 在使用相同纸张情况下压缩较小，总共切割成：2 x 2 = 4 张图片。每张大约：3921 x 2773 像素
# ║║
# ║║
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/七年级道法思维导图/七下道法思维导图/七下第三单元思维导图（新）.png
# 原始像素：3213 x 7160
# 原始 dpi：None
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：2 最右一帧占总宽：22.782446%
# 垂直页数：3 最下一帧占总高：2.039106%
# 可以考虑压缩 22.8% 以提高纸张利用率
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：1 最右一帧占总宽：100.000000%
# 垂直页数：3 最下一帧占总高：30.698324%
#
# 由于方案 2 比较节约纸张，总共切割成：1 x 3 = 3 张图片。每张大约：3507 x 2481 像素
# ===
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/七年级道法思维导图/七下道法思维导图/第一单元 青春时光.png
# 原始像素：2833 x 8655
# 原始 dpi：None
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：2 最右一帧占总宽：12.424991%
# 垂直页数：3 最下一帧占总高：18.960139%
# 可以考虑压缩 12.4% 以提高纸张利用率
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：1 最右一帧占总宽：100.000000%
# 垂直页数：4 最下一帧占总高：14.003466%
# 可以考虑压缩 14.0% 以提高纸张利用率
#
# 由于方案 2 比较节约纸张，总共切割成：1 x 4 = 4 张图片。每张大约：4033 x 2853 像素
# ====
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/七年级道法思维导图/七下道法思维导图/第二单元 做情绪情感的主人.png
# 原始像素：3677 x 7068
# 原始 dpi：None
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：2 最右一帧占总宽：32.526516%
# 垂直页数：3 最下一帧占总高：0.764007%
# 可以考虑压缩 0.8% 以提高纸张利用率
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：2 最右一帧占总宽：4.623334%
# 垂直页数：3 最下一帧占总高：29.796265%
# 可以考虑压缩 4.6% 以提高纸张利用率
#
# 由于方案 1 比较节约纸张，总共切割成：2 x 2 = 4 张图片。每张大约：3704 x 2620 像素
# ║║
# ║║
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/七年级道法思维导图/七上道法思维导图/第四单元 生命的思考.png
# 原始像素：3888 x 6294
# 原始 dpi：None
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：2 最右一帧占总宽：36.188272%
# 垂直页数：2 最下一帧占总高：44.280267%
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：2 最右一帧占总宽：9.799383%
# 垂直页数：3 最下一帧占总高：21.163012%
# 可以考虑压缩 9.8% 以提高纸张利用率
#
# 由于方案 1 在使用相同纸张情况下压缩较小，总共切割成：2 x 2 = 4 张图片。每张大约：3885 x 2748 像素
# ║║
# ║║
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/七年级道法思维导图/七上道法思维导图/第一单元 成长的节拍.png
# 原始像素：5038 x 6548
# 原始 dpi：None
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：3 最右一帧占总宽：1.508535%
# 垂直页数：2 最下一帧占总高：46.441662%
# 可以考虑压缩 1.5% 以提高纸张利用率
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：2 最右一帧占总宽：30.389043%
# 垂直页数：3 最下一帧占总高：24.221136%
# 可以考虑压缩 24.2% 以提高纸张利用率
#
# 由于方案 1 在使用相同纸张情况下压缩较小，总共切割成：2 x 2 = 4 张图片。每张大约：4391 x 3106 像素
# ║║
# ║║
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/七年级道法思维导图/七上道法思维导图/第三单元 师长情谊.png
# 原始像素：3986 x 6061
# 原始 dpi：None
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：2 最右一帧占总宽：37.757150%
# 垂直页数：2 最下一帧占总高：42.138261%
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：2 最右一帧占总宽：12.017060%
# 垂直页数：3 最下一帧占总高：18.132321%
# 可以考虑压缩 12.0% 以提高纸张利用率
#
# 由于方案 1 在使用相同纸张情况下压缩较小，总共切割成：2 x 2 = 4 张图片。每张大约：3963 x 2803 像素
# ║║
# ║║
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/九年级道法思维导图/九上/和谐与梦想.png
# 原始像素：4215 x 5315
# 原始 dpi：(72.009, 72.009)
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：2 最右一帧占总宽：41.138790%
# 垂直页数：2 最下一帧占总高：34.016933%
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：2 最右一帧占总宽：16.797153%
# 垂直页数：3 最下一帧占总高：6.641580%
# 可以考虑压缩 16.8% 以提高纸张利用率
#
# 由于方案 1 在使用相同纸张情况下压缩较小，总共切割成：2 x 2 = 4 张图片。每张大约：4131 x 2922 像素
# ║║
# ║║
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/九年级道法思维导图/九上/富强与创新.png
# 原始像素：1957 x 2621
# 原始 dpi：(72.009, 72.009)
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：1 最右一帧占总宽：100.000000%
# 垂直页数：1 最下一帧占总高：100.000000%
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：1 最右一帧占总宽：100.000000%
# 垂直页数：2 最下一帧占总高：5.341473%
# 可以考虑压缩 5.3% 以提高纸张利用率
#
# 由于方案 2 比较节约纸张，总共切割成：1 x 1 = 1 张图片。每张大约：3729 x 2638 像素
# =
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/九年级道法思维导图/九上/文明与家园.png
# 原始像素：3620 x 6996
# 原始 dpi：(72.009, 72.009)
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：2 最右一帧占总宽：31.464088%
# 垂直页数：2 最下一帧占总高：49.871355%
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：2 最右一帧占总宽：3.121547%
# 垂直页数：3 最下一帧占总高：29.073756%
# 可以考虑压缩 3.1% 以提高纸张利用率
#
# 由于方案 1 在使用相同纸张情况下压缩较小，总共切割成：2 x 2 = 4 张图片。每张大约：3651 x 2583 像素
# ║║
# ║║
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/九年级道法思维导图/九上/民主与法治.png
# 原始像素：4084 x 5246
# 原始 dpi：(72.009, 72.009)
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：2 最右一帧占总宽：39.250735%
# 垂直页数：2 最下一帧占总高：33.149066%
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：2 最右一帧占总宽：14.128306%
# 垂直页数：3 最下一帧占总高：5.413648%
# 可以考虑压缩 14.1% 以提高纸张利用率
#
# 由于方案 1 在使用相同纸张情况下压缩较小，总共切割成：2 x 2 = 4 张图片。每张大约：4037 x 2856 像素
# ║║
# ║║
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/九年级道法思维导图/九下/世界舞台上的中国.png
# 原始像素：4294 x 4007
# 原始 dpi：(72.009, 72.009)
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：2 最右一帧占总宽：42.221705%
# 垂直页数：2 最下一帧占总高：12.478163%
# 可以考虑压缩 12.5% 以提高纸张利用率
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：2 最右一帧占总宽：18.327899%
# 垂直页数：2 最下一帧占总高：38.083354%
# 可以考虑压缩 18.3% 以提高纸张利用率
#
# 由于方案 1 在使用相同纸张情况下压缩较小，总共切割成：2 x 2 = 4 张图片。每张大约：4184 x 2960 像素
# ║║
# ║║
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/九年级道法思维导图/九下/我们共同的世界.png
# 原始像素：4149 x 4430
# 原始 dpi：(72.009, 72.009)
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：2 最右一帧占总宽：40.202458%
# 垂直页数：2 最下一帧占总高：20.835214%
# 可以考虑压缩 20.8% 以提高纸张利用率
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：2 最右一帧占总宽：15.473608%
# 垂直页数：2 最下一帧占总高：43.995485%
# 可以考虑压缩 15.5% 以提高纸张利用率
#
# 由于方案 2 在使用相同纸张情况下压缩较小，总共切割成：2 x 2 = 4 张图片。每张大约：4084 x 2889 像素
# ==
# ==
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/八年级道法思维导图/八下第一单元思维导图.png
# 原始像素：2479 x 3941
# 原始 dpi：None
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：1 最右一帧占总宽：100.000000%
# 垂直页数：2 最下一帧占总高：11.012433%
# 可以考虑压缩 11.0% 以提高纸张利用率
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：1 最右一帧占总宽：100.000000%
# 垂直页数：2 最下一帧占总高：37.046435%
#
# 由于方案 1 比较节约纸张，总共切割成：1 x 2 = 2 张图片。每张大约：3507 x 2481 像素
# ║║
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/八年级道法思维导图/八上第三单元思维导图.png
# 原始像素：13137 x 14362
# 原始 dpi：None
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：6 最右一帧占总宽：5.572048%
# 垂直页数：5 最下一帧占总高：2.325581%
# 可以考虑压缩 2.3% 以提高纸张利用率
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：4 最右一帧占总宽：19.913222%
# 垂直页数：6 最下一帧占总高：13.626236%
# 可以考虑压缩 19.9% 以提高纸张利用率
#
# 由于方案 2 比较节约纸张，总共切割成：4 x 5 = 20 张图片。每张大约：4240 x 2999 像素
# =====
# =====
# =====
# =====
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/八年级道法思维导图/八上第二单元思维导图-pages-1.png
# 原始像素：3508 x 2480
# 原始 dpi：None
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：2 最右一帧占总宽：29.275941%
# 垂直页数：1 最下一帧占总高：100.000000%
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：2 最右一帧占总宽：0.028506%
# 垂直页数：1 最下一帧占总高：100.000000%
#
# 由于方案 2 在使用相同纸张情况下压缩较小，总共切割成：2 x 1 = 2 张图片。每张大约：3507 x 2481 像素
# =
# =
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/八年级道法思维导图/八上第二单元思维导图-pages-2.png
# 原始像素：3508 x 2480
# 原始 dpi：None
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：2 最右一帧占总宽：29.275941%
# 垂直页数：1 最下一帧占总高：100.000000%
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：2 最右一帧占总宽：0.028506%
# 垂直页数：1 最下一帧占总高：100.000000%
#
# 由于方案 2 在使用相同纸张情况下压缩较小，总共切割成：2 x 1 = 2 张图片。每张大约：3507 x 2481 像素
# =
# =
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/八年级道法思维导图/八下第三单元思维导图-3.png
# 原始像素：6400 x 3571
# 原始 dpi：None
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：3 最右一帧占总宽：22.468750%
# 垂直页数：2 最下一帧占总高：1.792215%
# 可以考虑压缩 1.8% 以提高纸张利用率
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：2 最右一帧占总宽：45.203125%
# 垂直页数：2 最下一帧占总高：30.523663%
#
# 由于方案 2 在使用相同纸张情况下压缩较小，总共切割成：2 x 2 = 4 张图片。每张大约：3507 x 2481 像素
# ==
# ==
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/八年级道法思维导图/八下第三单元思维导图-2.png
# 原始像素：6400 x 5736
# 原始 dpi：None
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：3 最右一帧占总宽：22.468750%
# 垂直页数：2 最下一帧占总高：38.859833%
# 可以考虑压缩 22.5% 以提高纸张利用率
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：2 最右一帧占总宽：45.203125%
# 垂直页数：3 最下一帧占总高：13.493724%
# 可以考虑压缩 13.5% 以提高纸张利用率
#
# 由于方案 2 在使用相同纸张情况下压缩较小，总共切割成：2 x 3 = 6 张图片。每张大约：4015 x 2840 像素
# ===
# ===
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/八年级道法思维导图/八上第一单元思维导图.png
# 原始像素：3508 x 2480
# 原始 dpi：None
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：2 最右一帧占总宽：29.275941%
# 垂直页数：1 最下一帧占总高：100.000000%
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：2 最右一帧占总宽：0.028506%
# 垂直页数：1 最下一帧占总高：100.000000%
#
# 由于方案 2 在使用相同纸张情况下压缩较小，总共切割成：2 x 1 = 2 张图片。每张大约：3507 x 2481 像素
# =
# =
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/八年级道法思维导图/八下第三单元思维导图-5.png
# 原始像素：4434 x 6399
# 原始 dpi：None
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：2 最右一帧占总宽：44.046008%
# 垂直页数：2 最下一帧占总高：45.194562%
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：2 最右一帧占总宽：20.906631%
# 垂直页数：3 最下一帧占总高：22.456634%
# 可以考虑压缩 20.9% 以提高纸张利用率
#
# 由于方案 1 在使用相同纸张情况下压缩较小，总共切割成：2 x 2 = 4 张图片。每张大约：4275 x 3024 像素
# ║║
# ║║
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/八年级道法思维导图/八下第三单元思维导图-4.png
# 原始像素：6400 x 3571
# 原始 dpi：None
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：3 最右一帧占总宽：22.468750%
# 垂直页数：2 最下一帧占总高：1.792215%
# 可以考虑压缩 1.8% 以提高纸张利用率
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：2 最右一帧占总宽：45.203125%
# 垂直页数：2 最下一帧占总高：30.523663%
#
# 由于方案 2 在使用相同纸张情况下压缩较小，总共切割成：2 x 2 = 4 张图片。每张大约：3507 x 2481 像素
# ==
# ==
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/八年级道法思维导图/八上第四单元思维导图.png
# 原始像素：10559 x 18700
# 原始 dpi：None
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：5 最右一帧占总宽：6.013827%
# 垂直页数：6 最下一帧占总高：6.229947%
# 可以考虑压缩 6.0% 以提高纸张利用率
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：4 最右一帧占总宽：0.359883%
# 垂直页数：8 最下一帧占总高：7.128342%
# 可以考虑压缩 0.4% 以提高纸张利用率
#
# 由于方案 1 比较节约纸张，总共切割成：4 x 5 = 20 张图片。每张大约：3554 x 2514 像素
# ║║║║║
# ║║║║║
# ║║║║║
# ║║║║║
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/八年级道法思维导图/八下第二单元思维导图-2.png
# 原始像素：3506 x 4959
# 原始 dpi：None
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：2 最右一帧占总宽：29.235596%
# 垂直页数：2 最下一帧占总高：29.280097%
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：1 最右一帧占总宽：100.000000%
# 垂直页数：2 最下一帧占总高：49.969752%
#
# 由于方案 2 比较节约纸张，总共切割成：1 x 2 = 2 张图片。每张大约：3507 x 2481 像素
# ==
# 完成
#
# 处理图像文件: /Users/I070019/Downloads/temp/道法思维导图（全）/八年级道法思维导图/八下第二单元思维导图-1.png
# 原始像素：3506 x 4959
# 原始 dpi：None
# 假设打印 dpi：300
#
# 假如切割成：2481 x 3507 (║)
# 水平页数：2 最右一帧占总宽：29.235596%
# 垂直页数：2 最下一帧占总高：29.280097%
#
# 假如切割成：3507 x 2481 (=)
# 水平页数：1 最右一帧占总宽：100.000000%
# 垂直页数：2 最下一帧占总高：49.969752%
#
# 由于方案 2 比较节约纸张，总共切割成：1 x 2 = 2 张图片。每张大约：3507 x 2481 像素
# ==
# 完成
